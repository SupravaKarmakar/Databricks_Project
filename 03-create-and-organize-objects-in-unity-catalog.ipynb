# %% [markdown]
# ## Exercise 1: Set Up the Catalog Structure
#
# You are a data engineer at **Lakeside University**, a mid-sized institution digitizing its academic operations. Your team is building a data platform in Azure Databricks and Unity Catalog to manage student records, course catalogues, and enrollment data.
#
# In this exercise, you create the top-level namespace structure: one `catalog` and three `schemas` following the **medallion architecture** naming pattern.
#
# Here's the full Unity Catalog structure you will create:
#
# ```txt
#
# Unity Catalog
# └── edu_dev64424280  [catalog]
#     │   tags: environment=development | university=lakeside | data_classification=internal
#     │
#     ├── bronze  [schema]
#     │   └── raw_files/  [managed volume]
#     │       └── students.csv
#     │
#     ├── silver  [schema]
#     │   ├── students  [table]
#     │   │   ├── student_id       BIGINT  NOT NULL  ← PK
#     │   │   ├── first_name       STRING
#     │   │   ├── last_name        STRING
#     │   │   ├── email            STRING
#     │   │   ├── enrollment_year  INT
#     │   │   ├── program          STRING
#     │   │   └── phone_number     STRING  (added in Exercise 6)
#     │   │
#     │   ├── courses  [table]
#     │   │   ├── course_id    BIGINT  NOT NULL  ← PK
#     │   │   ├── course_name  STRING
#     │   │   ├── department   STRING
#     │   │   └── credits      INT
#     │   │
#     │   ├── enrollments  [table]
#     │   │   ├── enrollment_id  BIGINT  NOT NULL  ← PK
#     │   │   ├── student_id     BIGINT            → FK → students.student_id
#     │   │   ├── course_id      BIGINT            → FK → courses.course_id
#     │   │   ├── semester       STRING
#     │   │   └── grade          DECIMAL(4,2)
#     │   │
#     │   ├── vw_student_enrollments  [view]
#     │   │   └── joins students + courses + enrollments
#     │   │
#     │   └── get_grade_classification(grade)  [function]
#     │       └── returns STRING  (A / B / C / D / F)
#     │
#     └── gold  [schema]
#         └── vw_department_enrollment_stats  [materialized view]
#             └── aggregates enrollments + courses
#                 (department, total_enrollments, avg_grade, distinct_students)
# ```

# %% [markdown]
# ### Task 1.1 — Create the development catalog
#
# Create a catalog called `edu_dev64424280` with a descriptive comment. This catalog serves as the **development environment** for Lakeside University's data platform.
#
# **Naming convention reminders:**
# - Use lowercase with underscores
# - No periods, spaces, forward slashes, or control characters
#
# > 🤖 **Genie Code tip:** Ask Genie Code:
# > *"How do I create a Unity Catalog catalog in Databricks SQL with a comment?"*
#
# **Hint:** Use the SQL command `CREATE CATALOG`.

# %%
# Since no default storage is enabled, we are inheriting the storage path from the default catalog's root.
# Use the current catalog to reliably find the workspace default catalog,
# regardless of its naming convention.
default_catalog = spark.catalog.currentCatalog()

storage_root = (
    spark.sql(f"DESCRIBE CATALOG EXTENDED {default_catalog}")
    .filter("info_name = 'Storage Root'")
    .select("info_value")
    .first()[0]
)
print (f"Storage root: {storage_root}")
# Out:
# Storage root: abfss://unity-catalog-storage@dbstoragei47akpw5pbb7a.dfs.core.windows.net/7405616090350293

# %%
# Create the edu_dev64424280 catalog with a descriptive comment
spark.sql(f"""
    CREATE CATALOG IF NOT EXISTS edu_dev64424280
    MANAGED LOCATION '{storage_root}'
    COMMENT 'Development catalog for Lakeside University data platform'
""")
print("Catalog edu_dev64424280 created successfully.")
# Out:
# Catalog edu_dev64424280 created successfully.

# %% [markdown]
# ### Task 1.2 — Create medallion schemas
#
# Within the `edu_dev64424280` catalog, create three schemas that implement the **medallion architecture**:
#
# | Schema | Purpose |
# |--------|---------|
# | `bronze` | Raw ingested data — unmodified source files |
# | `silver` | Cleaned, validated, and enriched data |
# | `gold` | Aggregated, analytics-ready data |
#
# > 🤖 **Genie Code tip:** Ask:
# > *"Show me how to create multiple schemas in a Databricks Unity Catalog catalog using SQL."*
#
# **Hint:** Use `CREATE SCHEMA IF NOT EXISTS catalog.schema_name` for each schema.

# %%
# %sql
-- Create the bronze, silver, and gold schemas inside edu_dev64424280

CREATE SCHEMA IF NOT EXISTS edu_dev64424280.bronze
COMMENT 'Raw ingested data - unmodified source files';

CREATE SCHEMA IF NOT EXISTS edu_dev64424280.silver
COMMENT 'Cleaned, validated, and enriched data';

CREATE SCHEMA IF NOT EXISTS edu_dev64424280.gold
COMMENT 'Aggregated, analytics-ready data';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Exercise 2: Create Tables with Constraints
#
# With the catalog structure in place, create the core tables for Lakeside University's academic data in the `silver` schema. You'll define **primary key** and **foreign key** constraints to document the data model. Note that in Unity Catalog, these constraints are informational — they help optimize queries but do not enforce referential integrity at write time.

# %% [markdown]
# ### Task 2.1 — Create the `students` table
#
# Create a managed Delta table `edu_dev64424280.silver.students` to store student records with the following columns:
#
# | Column | Type | Description |
# |--------|------|-------------|
# | `student_id` | BIGINT | Unique student identifier (primary key) |
# | `first_name` | STRING | Student's first name |
# | `last_name` | STRING | Student's last name |
# | `email` | STRING | University email address |
# | `enrollment_year` | INT | Year the student enrolled |
# | `program` | STRING | Degree program |
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I create a managed Delta table with a primary key constraint in Unity Catalog?"*
#
# **Hint:** Add `CONSTRAINT students_pk PRIMARY KEY (student_id)` at the end of the column list.

# %%
# %sql
-- Create edu_dev64424280.silver.students with a primary key constraint
CREATE TABLE IF NOT EXISTS edu_dev64424280.silver.students (
  student_id BIGINT NOT NULL,
  first_name STRING,
  last_name STRING,
  email STRING,
  enrollment_year INT,
  program STRING,
  CONSTRAINT students_pk PRIMARY KEY (student_id)
)
COMMENT 'Silver table storing cleaned student records for Lakeside University'

# %% [markdown]
# ### Task 2.2 — Create the `courses` table
#
# Create `edu_dev64424280.silver.courses` with the following columns:
#
# | Column | Type | Description |
# |--------|------|-------------|
# | `course_id` | BIGINT | Unique course identifier (primary key) |
# | `course_name` | STRING | Full name of the course |
# | `department` | STRING | Academic department offering the course |
# | `credits` | INT | Number of academic credits |
#
# > 🤖 **Genie Code tip:** Ask:
# > *"Write a CREATE TABLE statement for a courses table in Databricks Unity Catalog with a primary key constraint."*

# %%
# %sql
-- Create edu_dev64424280.silver.courses with a primary key constraint
CREATE TABLE IF NOT EXISTS edu_dev64424280.silver.courses (
  course_id BIGINT NOT NULL,
  course_name STRING,
  department STRING,
  credits INT,
  CONSTRAINT courses_pk PRIMARY KEY (course_id)
)
COMMENT 'Silver table storing course catalog for Lakeside University'

# %% [markdown]
# ### Task 2.3 — Create the `enrollments` table with foreign keys
#
# Create `edu_dev64424280.silver.enrollments` to record which students are enrolled in which courses. This table must reference both `students` and `courses` via foreign key constraints.
#
# | Column | Type | Description |
# |--------|------|-------------|
# | `enrollment_id` | BIGINT | Unique enrollment record (primary key) |
# | `student_id` | BIGINT | References `students.student_id` |
# | `course_id` | BIGINT | References `courses.course_id` |
# | `semester` | STRING | Academic semester (e.g., `Spring 2023`) |
# | `grade` | DECIMAL(4,2) | Numerical grade on a 0.0–10.0 scale |
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I add foreign key constraints referencing other tables when creating a table in Databricks Unity Catalog?"*
#
# **Hint:** Use `CONSTRAINT <name> FOREIGN KEY (<col>) REFERENCES <catalog>.<schema>.<table>(<col>)` for each foreign key.

# %%
# %sql
-- Create edu_dev64424280.silver.enrollments with primary key and two foreign key constraints
CREATE TABLE IF NOT EXISTS edu_dev64424280.silver.enrollments (
  enrollment_id BIGINT NOT NULL,
  student_id BIGINT,
  course_id BIGINT,
  semester STRING,
  grade DECIMAL(4,2),
  CONSTRAINT enrollments_pk PRIMARY KEY (enrollment_id),
  CONSTRAINT enrollments_students_fk FOREIGN KEY (student_id) REFERENCES edu_dev64424280.silver.students(student_id),
  CONSTRAINT enrollments_courses_fk FOREIGN KEY (course_id) REFERENCES edu_dev64424280.silver.courses(course_id)
)
COMMENT 'Silver table storing student enrollment records with foreign keys to students and courses'

# %% [markdown]
# ### Sample data — run this cell
#
# The following cell inserts sample data into your three tables. **Run it without modification** before continuing to Exercise 3.

# %%
# %sql
-- Populate students
INSERT INTO edu_dev64424280.silver.students VALUES
(1001, 'Emma',   'Watson',    'emma.watson@lakeside.edu',    2022, 'Computer Science'),
(1002, 'Liam',   'Ahmed',     'liam.ahmed@lakeside.edu',     2023, 'Data Science'),
(1003, 'Sofia',  'Chen',      'sofia.chen@lakeside.edu',     2021, 'Mathematics'),
(1004, 'James',  'Okonkwo',   'james.okonkwo@lakeside.edu',  2022, 'Computer Science'),
(1005, 'Aisha',  'Patel',     'aisha.patel@lakeside.edu',    2023, 'Data Science'),
(1006, 'Noah',   'Yamamoto',  'noah.yamamoto@lakeside.edu',  2020, 'Mathematics'),
(1007, 'Olivia', 'Kowalski',  'olivia.kowalski@lakeside.edu',2021, 'Computer Science'),
(1008, 'Carlos', 'Reyes',     'carlos.reyes@lakeside.edu',   2022, 'Data Science'),
(1009, 'Mei',    'Lindqvist', 'mei.lindqvist@lakeside.edu',  2023, 'Mathematics'),
(1010, 'Jake',   'OBrien',    'jake.obrien@lakeside.edu',    2020, 'Computer Science');

-- Populate courses
INSERT INTO edu_dev64424280.silver.courses VALUES
(101, 'Introduction to Programming',   'Computer Science', 3),
(102, 'Data Structures',               'Computer Science', 4),
(103, 'Statistics for Data Science',   'Data Science',     3),
(104, 'Machine Learning Fundamentals', 'Data Science',     4),
(105, 'Calculus I',                    'Mathematics',      4),
(106, 'Linear Algebra',                'Mathematics',      3);

-- Populate enrollments
INSERT INTO edu_dev64424280.silver.enrollments VALUES
(1,  1001, 101, 'Spring 2023', 8.50),
(2,  1001, 102, 'Fall 2023',   7.80),
(3,  1002, 103, 'Spring 2023', 9.20),
(4,  1002, 104, 'Fall 2023',   6.50),
(5,  1003, 105, 'Spring 2022', 7.00),
(6,  1003, 106, 'Fall 2022',   8.00),
(7,  1004, 101, 'Fall 2022',   6.80),
(8,  1005, 103, 'Spring 2023', 9.00),
(9,  1006, 105, 'Fall 2020',   7.50),
(10, 1007, 102, 'Spring 2022', 8.20),
(11, 1008, 104, 'Fall 2023',   7.30),
(12, 1009, 106, 'Spring 2023', 8.80),
(13, 1010, 101, 'Fall 2021',   5.50),
(14, 1004, 102, 'Spring 2023', 7.10),
(15, 1005, 104, 'Fall 2023',   8.90);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>15</td><td>15</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 3: Create Views
#
# Views provide a virtual layer over your tables, simplifying access to joined data and pre-computing expensive aggregations. In this exercise, you create a **standard view** for combined enrollment records and a **materialized view** in the `gold` schema to serve the Lakeside University analytics team with pre-aggregated department statistics.

# %% [markdown]
# ### Task 3.1 — Create a standard view
#
# Create a view `edu_dev64424280.silver.vw_student_enrollments` that presents a combined, human-readable view of student enrollment records. It should include:
#
# - Student full name (concatenate `first_name` and `last_name` with a space between them)
# - Student `email`
# - `course_name`
# - `department`
# - `semester`
# - `grade`
#
# > 🤖 **Genie Code tip:** Ask:
# > *"Write a SQL view in Azure Databricks that joins three tables: students, courses, and enrollments"*
#
# **Hint:** Use `CONCAT(first_name, ' ', last_name)` or the `||` operator to combine names. You need to join all three silver tables.

# %%
# %sql
-- Create the edu_dev64424280.silver.vw_student_enrollments view
CREATE OR REPLACE VIEW edu_dev64424280.silver.vw_student_enrollments AS
SELECT
  CONCAT(s.first_name, ' ', s.last_name) AS full_name,
  s.email,
  c.course_name,
  c.department,
  e.semester,
  e.grade
FROM edu_dev64424280.silver.students s
JOIN edu_dev64424280.silver.enrollments e ON s.student_id = e.student_id
JOIN edu_dev64424280.silver.courses c ON e.course_id = c.course_id

# %% [markdown]
# ### Task 3.2 — Create a materialized view for department statistics
#
# Create a materialized view `edu_dev64424280.gold.vw_department_enrollment_stats` that pre-computes the following per academic department:
#
# | Output column | Description |
# |--------------|-------------|
# | `department` | Academic department name |
# | `total_enrollments` | Total number of enrollment records |
# | `avg_grade` | Average grade, rounded to 2 decimal places |
# | `distinct_students` | Number of unique students enrolled |
#
# > 🤖 **Genie Code tip:** Ask:
# > *"What is the syntax for creating a materialized view in Azure Databricks that aggregates data from two joined tables?"*
#
# **Hint:** Use `CREATE MATERIALIZED VIEW`, join `enrollments` with `courses`, and use `COUNT()`, `ROUND(AVG(...), 2)`, and `COUNT(DISTINCT ...)`.
#
# > [!NOTE]
# > Materialized views require a SQL warehouse to run. If this cell fails, check the compute selector at the top of the notebook and switch from **Serverless** compute to a **Serverless SQL warehouse**.

# %%
# %sql
-- Create the edu_dev64424280.gold.vw_department_enrollment_stats materialized view
CREATE MATERIALIZED VIEW IF NOT EXISTS edu_dev64424280.gold.vw_department_enrollment_stats
AS
SELECT
  c.department,
  COUNT(*) AS total_enrollments,
  ROUND(AVG(e.grade), 2) AS avg_grade,
  COUNT(DISTINCT e.student_id) AS distinct_students
FROM edu_dev64424280.silver.enrollments e
JOIN edu_dev64424280.silver.courses c ON e.course_id = c.course_id
GROUP BY c.department
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>result</th></tr></thead><tbody><tr><td>The operation was successfully executed.</td></tr></tbody></table></div>

# %% [markdown]
# **✅ Test your materialized view** — Run the following query to verify it returns per-department aggregates:
#
# You should see one row per academic department with columns for `total_enrollments`, `avg_grade`, and `distinct_students`.

# %%
# %sql
SELECT * FROM edu_dev64424280.gold.vw_department_enrollment_stats;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>department</th><th>total_enrollments</th><th>avg_grade</th><th>distinct_students</th></tr></thead><tbody><tr><td>Mathematics</td><td>4</td><td>7.83</td><td>3</td></tr><tr><td>Data Science</td><td>5</td><td>8.18</td><td>3</td></tr><tr><td>Computer Science</td><td>6</td><td>7.32</td><td>4</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 4: Create a Volume and Read Files
#
# Volumes extend Unity Catalog governance to files, not just structured tables. In this exercise, you create a **managed volume** in the `bronze` schema to serve as a landing zone for raw CSV files — simulating files arriving from Lakeside University's external student information system.

# %% [markdown]
# ### Task 4.1 — Create a managed volume
#
# Create a managed volume named `raw_files` in the `edu_dev64424280.bronze` schema. This will serve as the landing area for raw data files.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I create a managed volume in Unity Catalog using a SQL statement?"*
#
# **Hint:** Use `CREATE VOLUME IF NOT EXISTS <catalog>.<schema>.<volume>`.

# %%
# %sql
-- Create the raw_files managed volume in edu_dev64424280.bronze
CREATE VOLUME IF NOT EXISTS edu_dev64424280.bronze.raw_files
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 4.2 — Write a CSV file to the volume
#
# The following Python cell writes a sample student CSV file directly into your new volume. **Run it without modification.**

# %%
# Write a sample student CSV file to the volume — run this cell without modification
csv_content = """student_id,first_name,last_name,email,enrollment_year,program
1001,Emma,Watson,emma.watson@lakeside.edu,2022,Computer Science
1002,Liam,Ahmed,liam.ahmed@lakeside.edu,2023,Data Science
1003,Sofia,Chen,sofia.chen@lakeside.edu,2021,Mathematics
1004,James,Okonkwo,james.okonkwo@lakeside.edu,2022,Computer Science
1005,Aisha,Patel,aisha.patel@lakeside.edu,2023,Data Science
1006,Noah,Yamamoto,noah.yamamoto@lakeside.edu,2020,Mathematics
1007,Olivia,Kowalski,olivia.kowalski@lakeside.edu,2021,Computer Science
1008,Carlos,Reyes,carlos.reyes@lakeside.edu,2022,Data Science
1009,Mei,Lindqvist,mei.lindqvist@lakeside.edu,2023,Mathematics
1010,Jake,OBrien,jake.obrien@lakeside.edu,2020,Computer Science"""

dbutils.fs.put("/Volumes/edu_dev64424280/bronze/raw_files/students.csv", csv_content, overwrite=True)
print("students.csv written to /Volumes/edu_dev64424280/bronze/raw_files/")
# Out:
# Wrote 692 bytes.
# students.csv written to /Volumes/edu_dev64424280/bronze/raw_files/

# %% [markdown]
# ### Task 4.3 — Read the CSV from the volume into a DataFrame
#
# Read the CSV file you just placed in the volume into a Spark DataFrame and display its contents. The file is at `/Volumes/edu_dev64424280/bronze/raw_files/students.csv`.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I read a CSV file with a header row from a Unity Catalog volume path in PySpark?"*
#
# **Hint:** Use `spark.read.csv(path, header=True, inferSchema=True)` then call `.display()` or `.show()` on the result.

# %%
# Read /Volumes/edu_dev64424280/bronze/raw_files/students.csv into a Spark DataFrame and display it
df = spark.read.csv("/Volumes/edu_dev64424280/bronze/raw_files/students.csv", header=True, inferSchema=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>student_id</th><th>first_name</th><th>last_name</th><th>email</th><th>enrollment_year</th><th>program</th></tr></thead><tbody><tr><td>1001</td><td>Emma</td><td>Watson</td><td>emma.watson@lakeside.edu</td><td>2022</td><td>Computer Science</td></tr><tr><td>1002</td><td>Liam</td><td>Ahmed</td><td>liam.ahmed@lakeside.edu</td><td>2023</td><td>Data Science</td></tr><tr><td>1003</td><td>Sofia</td><td>Chen</td><td>sofia.chen@lakeside.edu</td><td>2021</td><td>Mathematics</td></tr><tr><td>1004</td><td>James</td><td>Okonkwo</td><td>james.okonkwo@lakeside.edu</td><td>2022</td><td>Computer Science</td></tr><tr><td>1005</td><td>Aisha</td><td>Patel</td><td>aisha.patel@lakeside.edu</td><td>2023</td><td>Data Science</td></tr><tr><td>1006</td><td>Noah</td><td>Yamamoto</td><td>noah.yamamoto@lakeside.edu</td><td>2020</td><td>Mathematics</td></tr><tr><td>1007</td><td>Olivia</td><td>Kowalski</td><td>olivia.kowalski@lakeside.edu</td><td>2021</td><td>Computer Science</td></tr><tr><td>1008</td><td>Carlos</td><td>Reyes</td><td>carlos.reyes@lakeside.edu</td><td>2022</td><td>Data Science</td></tr><tr><td>1009</td><td>Mei</td><td>Lindqvist</td><td>mei.lindqvist@lakeside.edu</td><td>2023</td><td>Mathematics</td></tr><tr><td>1010</td><td>Jake</td><td>OBrien</td><td>jake.obrien@lakeside.edu</td><td>2020</td><td>Computer Science</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 5: Create a Reusable SQL Function
#
# Unity Catalog allows you to create **governed, reusable functions** that encapsulate business logic. Instead of repeating grade conversion logic in every query, you'll write it once as a SQL function and call it from any notebook or query in the workspace.

# %% [markdown]
# ### Task 5.1 — Create a grade classification function
#
# Create a SQL scalar function `edu_dev64424280.silver.get_grade_classification` that accepts a `grade DECIMAL(4,2)` and returns a `STRING` letter classification based on the scale used at Lakeside University:
#
# | Grade range | Classification |
# |-------------|----------------|
# | ≥ 8.5 | `'A'` |
# | ≥ 7.0 | `'B'` |
# | ≥ 5.5 | `'C'` |
# | ≥ 4.0 | `'D'` |
# | < 4.0 | `'F'` |
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I create a SQL scalar function in Unity Catalog that uses a CASE expression to return a letter grade based on a numeric score?"*
#
# **Hint:** Use `CREATE FUNCTION ... RETURNS STRING RETURN CASE WHEN ... END`.

# %%
# %sql
-- Create the edu_dev64424280.silver.get_grade_classification function
CREATE OR REPLACE FUNCTION edu_dev64424280.silver.get_grade_classification(grade DECIMAL(4,2))
RETURNS STRING
COMMENT 'Returns a letter classification (A/B/C/D/F) for a numeric grade on a 0-10 scale'
RETURN
  CASE
    WHEN grade >= 8.5 THEN 'A'
    WHEN grade >= 7.0 THEN 'B'
    WHEN grade >= 5.5 THEN 'C'
    WHEN grade >= 4.0 THEN 'D'
    ELSE 'F'
  END
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 5.2 — Test the function
#
# Query `edu_dev64424280.silver.enrollments` and apply your new function to produce a `grade_classification` column for each row. Include: `enrollment_id`, `student_id`, `course_id`, `semester`, `grade`, and `grade_classification`.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I call a Unity Catalog user-defined function in a SELECT statement in Azure Databricks?"*

# %%
# %sql
-- Query enrollments and apply the grade classification function
SELECT
  enrollment_id,
  student_id,
  course_id,
  semester,
  grade,
  edu_dev64424280.silver.get_grade_classification(grade) AS grade_classification
FROM edu_dev64424280.silver.enrollments
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>enrollment_id</th><th>student_id</th><th>course_id</th><th>semester</th><th>grade</th><th>grade_classification</th></tr></thead><tbody><tr><td>1</td><td>1001</td><td>101</td><td>Spring 2023</td><td>8.50</td><td>A</td></tr><tr><td>2</td><td>1001</td><td>102</td><td>Fall 2023</td><td>7.80</td><td>B</td></tr><tr><td>3</td><td>1002</td><td>103</td><td>Spring 2023</td><td>9.20</td><td>A</td></tr><tr><td>4</td><td>1002</td><td>104</td><td>Fall 2023</td><td>6.50</td><td>C</td></tr><tr><td>5</td><td>1003</td><td>105</td><td>Spring 2022</td><td>7.00</td><td>B</td></tr><tr><td>6</td><td>1003</td><td>106</td><td>Fall 2022</td><td>8.00</td><td>B</td></tr><tr><td>7</td><td>1004</td><td>101</td><td>Fall 2022</td><td>6.80</td><td>C</td></tr><tr><td>8</td><td>1005</td><td>103</td><td>Spring 2023</td><td>9.00</td><td>A</td></tr><tr><td>9</td><td>1006</td><td>105</td><td>Fall 2020</td><td>7.50</td><td>B</td></tr><tr><td>10</td><td>1007</td><td>102</td><td>Spring 2022</td><td>8.20</td><td>B</td></tr><tr><td>11</td><td>1008</td><td>104</td><td>Fall 2023</td><td>7.30</td><td>B</td></tr><tr><td>12</td><td>1009</td><td>106</td><td>Spring 2023</td><td>8.80</td><td>A</td></tr><tr><td>13</td><td>1010</td><td>101</td><td>Fall 2021</td><td>5.50</td><td>C</td></tr><tr><td>14</td><td>1004</td><td>102</td><td>Spring 2023</td><td>7.10</td><td>B</td></tr><tr><td>15</td><td>1005</td><td>104</td><td>Fall 2023</td><td>8.90</td><td>A</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 6: DDL Operations
#
# Unity Catalog objects evolve over time as requirements change. In this exercise, you use `ALTER` statements to:
# 1. Extend the `students` table with a new column.
# 2. Apply governance **tags** to the `edu_dev64424280` catalog.

# %% [markdown]
# ### Task 6.1 — Add a column to the students table
#
# The student registration system has been updated to capture phone numbers. Add a nullable `phone_number` column of type `STRING` to `edu_dev64424280.silver.students`.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I add a new nullable column to an existing Delta table in Azure Databricks using SQL?"*
#
# **Hint:** Use `ALTER TABLE`.

# %%
# %sql
-- Add a phone_number (STRING) column to edu_dev64424280.silver.students
ALTER TABLE edu_dev64424280.silver.students ADD COLUMN phone_number STRING

# %% [markdown]
# ### Task 6.2 — Apply tags to the catalog
#
# Apply the following tags to the `edu_dev64424280` catalog to support governance and discoverability:
#
# | Tag key | Tag value |
# |---------|----------|
# | `environment` | `'development'` |
# | `university` | `'lakeside'` |
# | `data_classification` | `'internal'` |
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I set metadata tags on a Unity Catalog catalog using the ALTER CATALOG statement in Databricks?"*

# %%
# %sql
-- Apply the three tags to the edu_dev64424280 catalog using ALTER CATALOG ... SET TAGS
ALTER CATALOG edu_dev64424280
SET TAGS ('environment' = 'development', 'university' = 'lakeside', 'data_classification' = 'internal');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 6.3 — Verify your work
#
# Run the following cells to confirm your catalog structure, table schemas, and tags are all in place. Compare the output with what you created throughout this lab.

# %%
# %sql
-- Show all tables and views in the silver schema
SHOW TABLES IN edu_dev64424280.silver;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>silver</td><td>courses</td><td>false</td></tr><tr><td>silver</td><td>enrollments</td><td>false</td></tr><tr><td>silver</td><td>students</td><td>false</td></tr><tr><td>silver</td><td>vw_student_enrollments</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
-- Describe the students table — verify the new phone_number column is present
DESCRIBE TABLE edu_dev64424280.silver.students;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>student_id</td><td>bigint</td><td>null</td></tr><tr><td>first_name</td><td>string</td><td>null</td></tr><tr><td>last_name</td><td>string</td><td>null</td></tr><tr><td>email</td><td>string</td><td>null</td></tr><tr><td>enrollment_year</td><td>int</td><td>null</td></tr><tr><td>program</td><td>string</td><td>null</td></tr><tr><td>phone_number</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
-- Show catalog details
DESCRIBE CATALOG EXTENDED edu_dev64424280;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>info_name</th><th>info_value</th></tr></thead><tbody><tr><td>Catalog Name</td><td>edu_dev64424280</td></tr><tr><td>Comment</td><td>Development catalog for Lakeside University data platform</td></tr><tr><td>Owner</td><td>user1-64424280@lodsprodmca.onmicrosoft.com</td></tr><tr><td>Catalog Type</td><td>Regular</td></tr><tr><td>Created By</td><td>user1-64424280@lodsprodmca.onmicrosoft.com</td></tr><tr><td>Created At</td><td>2026-08-25 AD at 07:28:27 UTC</td></tr><tr><td>Updated By</td><td>user1-64424280@lodsprodmca.onmicrosoft.com</td></tr><tr><td>Updated At</td><td>2026-08-25 AD at 08:03:13 UTC</td></tr><tr><td>Storage Root</td><td>abfss://unity-catalog-storage@dbstoragei47akpw5pbb7a.dfs.core.windows.net/7405616090350293</td></tr><tr><td>Storage Location</td><td>abfss://unity-catalog-storage@dbstoragei47akpw5pbb7a.dfs.core.windows.net/7405616090350293/__unitystorage/catalogs/1d716b19-f348-4a72-95a8-5aeaf0af88a7</td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_canadacentral)</td></tr></tbody></table></div>

# %%
# %sql 
-- Query tags via information schema (structured way)
SELECT *
FROM system.information_schema.catalog_tags
WHERE catalog_name = 'edu_dev64424280'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog_name</th><th>tag_name</th><th>tag_value</th></tr></thead><tbody><tr><td>edu_dev64424280</td><td>environment</td><td>development</td></tr><tr><td>edu_dev64424280</td><td>university</td><td>lakeside</td></tr><tr><td>edu_dev64424280</td><td>data_classification</td><td>internal</td></tr></tbody></table></div>

# %% [markdown]
# ---
#
# ## Next steps
#
# You have completed all notebook exercises. Return to the **lab instructions** and continue with:
#
# - **Exercise**: Configure an AI/BI Genie Space (optional)
