# %% [markdown]
# ## Exercise 1: Access Control
#
# You are a data engineer at **NorthMart Retail**, a national supermarket chain. Your team stores customer and transaction data in Unity Catalog. Before any analyst can run queries, you must first create the catalog, the schema, and populate a customer table — then grant the `retail-analysts` group the permissions they need.
#
# > ⚠️ Before starting this exercise, ensure you have created the `retail-analysts` group in Databricks and added your own user account to it. See the lab setup instructions.

# %% [markdown]
# ### Task 1.1 — Create the catalog, schema, and customers table
#
# The cell below sets up all the objects needed for this exercise:
# - Creates a catalog called `retail_catalog64457032` to hold all NorthMart data assets.
# - Creates a schema called `security_lab` inside it.
# - Creates a managed Delta table `retail_catalog64457032.security_lab.customers` and populates it with six sample customer records. These rows will be used throughout the rest of this exercise to demonstrate row filtering and column masking.
#
# | customer_id | customer_name   | email                   | region | total_spend | tier     |
# |-------------|-----------------|-------------------------|--------|-------------|----------|
# | 1           | Alice Johnson   | alice@northmart.com     | North  | 5200.00     | Standard |
# | 2           | Bob Martinez    | bob@northmart.com       | South  | 8100.00     | Premium  |
# | 3           | Carol Lee       | carol@northmart.com     | North  | 3400.00     | Standard |
# | 4           | David Chen      | david@northmart.com     | East   | 7800.00     | Premium  |
# | 5           | Eve Patel       | eve@northmart.com       | West   | 6200.00     | Standard |
# | 6           | Frank Kim       | frank@northmart.com     | South  | 4100.00     | Standard |
#
# Run the cell to provision these objects.

# %%
# Since no default storage is enabled, we are inheriting the storage path from the default catalog's root.
# Use the current catalog to reliably find the workspace default catalog,
# regardless of its naming convention.
default_catalog = spark.catalog.currentCatalog()

storage_root = (
    spark.sql(f"DESCRIBE CATALOG EXTENDED {default_catalog}")
    .filter("info_name = 'Storage Root'")
    .select("info_value")
    .first()[0]
)
print (f"Storage root: {storage_root}")

spark.sql(f"""
    CREATE CATALOG IF NOT EXISTS retail_catalog64457032
    MANAGED LOCATION '{storage_root}'
    COMMENT 'Catalog for NorthMart Retail data assets'
""")
# Out:
# Storage root: abfss://unity-catalog-storage@dbstorageb6ajvpxbwxw5g.dfs.core.windows.net/7405618597338272
# DataFrame[]

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS retail_catalog64457032.security_lab
  COMMENT 'Schema used for the security lab exercises';

CREATE OR REPLACE TABLE retail_catalog64457032.security_lab.customers AS
SELECT * FROM VALUES
  (1, 'Alice Johnson', 'alice@northmart.com', 'North', 5200.00, 'Standard'),
  (2, 'Bob Martinez',  'bob@northmart.com',   'South', 8100.00, 'Premium'),
  (3, 'Carol Lee',     'carol@northmart.com', 'North', 3400.00, 'Standard'),
  (4, 'David Chen',    'david@northmart.com', 'East',  7800.00, 'Premium'),
  (5, 'Eve Patel',     'eve@northmart.com',   'West',  6200.00, 'Standard'),
  (6, 'Frank Kim',     'frank@northmart.com', 'South', 4100.00, 'Standard')
  AS t(customer_id, customer_name, email, region, total_spend, tier);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 1.2 — Grant permissions to the retail-analysts group
#
# The `retail-analysts` group needs to query the `customers` table. Grant the necessary privileges at all required levels of the Unity Catalog hierarchy:
#
# - `USE CATALOG` on `retail_catalog64457032`
# - `USE SCHEMA` on `retail_catalog64457032.security_lab`
# - `SELECT` on `retail_catalog64457032.security_lab.customers`
#
# > 🤖 **Genie Code tip:** Ask:
# > *"What SQL grants are needed to allow a Databricks group to SELECT from a Unity Catalog table?"*
#
# **Hint:** Use `GRANT <privilege> ON <object type> <object name> TO \`retail-analysts\``.

# %%
# %sql
-- Grant the necessary privileges at each level of the Unity Catalog hierarchy
GRANT USE CATALOG ON CATALOG retail_catalog64457032 TO `retail-analysts64457032`;
GRANT USE SCHEMA ON SCHEMA retail_catalog64457032.security_lab TO `retail-analysts64457032`;
GRANT SELECT ON TABLE retail_catalog64457032.security_lab.customers TO `retail-analysts64457032`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 1.3 — Verify the granted permissions
#
# Verify that the privileges were correctly assigned. Use `SHOW GRANTS` to display all privileges on the `customers` table.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I use SHOW GRANTS to verify permissions on a Unity Catalog table?"*
#
# **Expected result:** You should see `retail-analysts` listed with the `SELECT` privilege.

# %%
# %sql
SHOW GRANTS ON TABLE retail_catalog64457032.security_lab.customers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody><tr><td>retail-analysts64457032</td><td>SELECT</td><td>TABLE</td><td>retail_catalog64457032.security_lab.customers</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 2: Row Filtering
#
# NorthMart Retail's regional analysts should only see customer records for their own region. You will implement a **row filter function** that restricts rows based on who is querying the table.
#
# Since you cannot create multiple user accounts, you will write a filter that shows only `North` region rows to everyone *except* for your own user account, which sees all rows. This simulates what a regional analyst would experience.

# %% [markdown]
# ### Task 2.1 — Create a row filter function
#
# Create a SQL function `retail_catalog64457032.security_lab.region_filter` that takes a `region` parameter of type `STRING` and returns `TRUE` if:
# - the `region` is `'North'`, **OR**
# - the current user is your own account (replace `your@email.com` with your actual email).
#
# This means: unless you are the privileged user, only `North` region rows will be visible.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I create a row filter function in Databricks Unity Catalog that uses current_user() to control access?"*
#
# **Hint:** Use `CREATE OR REPLACE FUNCTION ... RETURN <boolean expression using current_user()>`.

# %%
# %sql
-- Create the region_filter function in retail_catalog64457032.security_lab
-- Replace 'your@email.com' with your actual Databricks user email

CREATE OR REPLACE FUNCTION retail_catalog64457032.security_lab.region_filter(region STRING)
RETURNS BOOLEAN
RETURN (region = 'North' OR current_user() = 'User1-64457032@LODSPRODMCA.onmicrosoft.com');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 2.2 — Apply the row filter to the customers table
#
# Attach the `region_filter` function to the `customers` table so that it is automatically applied to every query against that table.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I set a row filter on a Unity Catalog table in Azure Databricks?"*
#
# **Hint:** Use `ALTER TABLE ... SET ROW FILTER <function> ON (<column>)`.

# %%
# %sql
-- Apply region_filter to retail_catalog64457032.security_lab.customers on the region column
ALTER TABLE retail_catalog64457032.security_lab.customers
SET ROW FILTER retail_catalog64457032.security_lab.region_filter ON (region);

# %% [markdown]
# ### Task 2.3 — Test the row filter
#
# Query the `customers` table. Because your own email is listed as the privileged user in the filter function, you should see **all 6 rows**.
#
# If you had logged in as someone else (not your email), you would only see the 2 `North` region rows.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How can I verify which user is currently running a query in Databricks using SQL?"*

# %%
# %sql
-- Verify the current user
SELECT current_user();

-- Verify the current user
-- The current_user() function returns the email of the user running the query
SELECT current_user();

-- Query the customers table to observe the row filter in action
SELECT * FROM retail_catalog64457032.security_lab.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>email</th><th>region</th><th>total_spend</th><th>tier</th></tr></thead><tbody><tr><td>1</td><td>Alice Johnson</td><td>alice@northmart.com</td><td>North</td><td>5200.00</td><td>Standard</td></tr><tr><td>3</td><td>Carol Lee</td><td>carol@northmart.com</td><td>North</td><td>3400.00</td><td>Standard</td></tr></tbody></table></div>

# %% [markdown]
# ➡️ Tip: update the email address in the row filter function you created earlier, and test again. Observe the output when querying the customers table.

# %% [markdown]
# ### Task 2.4 — Remove the row filter
#
# Now remove the row filter from the `customers` table. After removing it, query the table again to confirm **all 6 rows** are now returned regardless of user context.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I remove a row filter from a Unity Catalog table?"*
#
# **Hint:** Use `ALTER TABLE ... DROP ROW FILTER`.

# %%
# %sql
-- Remove the row filter from retail_catalog64457032.security_lab.customers
ALTER TABLE retail_catalog64457032.security_lab.customers DROP ROW FILTER;

-- Query the table to confirm all 6 rows are visible
SELECT * FROM retail_catalog64457032.security_lab.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>email</th><th>region</th><th>total_spend</th><th>tier</th></tr></thead><tbody><tr><td>1</td><td>Alice Johnson</td><td>alice@northmart.com</td><td>North</td><td>5200.00</td><td>Standard</td></tr><tr><td>2</td><td>Bob Martinez</td><td>bob@northmart.com</td><td>South</td><td>8100.00</td><td>Premium</td></tr><tr><td>3</td><td>Carol Lee</td><td>carol@northmart.com</td><td>North</td><td>3400.00</td><td>Standard</td></tr><tr><td>4</td><td>David Chen</td><td>david@northmart.com</td><td>East</td><td>7800.00</td><td>Premium</td></tr><tr><td>5</td><td>Eve Patel</td><td>eve@northmart.com</td><td>West</td><td>6200.00</td><td>Standard</td></tr><tr><td>6</td><td>Frank Kim</td><td>frank@northmart.com</td><td>South</td><td>4100.00</td><td>Standard</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 3: Column Masking
#
# Customer email addresses are PII and must be masked for users who aren't privileged. You will create a **column mask function** that hides the full email address for most users, applying it to the `email` column of the `customers` table.

# %% [markdown]
# ### Task 3.1 — Create a column mask function
#
# Create a SQL function `retail_catalog64457032.security_lab.mask_email` that takes an `email` parameter of type `STRING` and:
# - Returns the **full email** if the current user is your own account.
# - Returns a **masked value** (e.g. `'***@***.com'`) for all other users.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I create a column masking function in Databricks Unity Catalog that uses current_user() to decide whether to return the real or masked value?"*
#
# **Hint:** Use a `CASE WHEN current_user() = '...' THEN email ELSE '***@***.com' END` pattern inside the function body.

# %%
# %sql
-- Create the mask_email function in retail_catalog64457032.security_lab
-- Replace 'your@email.com' with your actual Databricks user email

CREATE OR REPLACE FUNCTION retail_catalog64457032.security_lab.mask_email(email STRING)
RETURNS STRING
RETURN CASE
  WHEN current_user() = 'User1-64457032@LODSPRODMCA.onmicrosoft.com' THEN email
  ELSE '***@***.com'
END;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### Task 3.2 — Apply the column mask to the email column
#
# Apply the `mask_email` function as a column mask on the `email` column of the `customers` table.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I set a column mask on a Unity Catalog table column in Azure Databricks using SQL?"*
#
# **Hint:** Use `ALTER TABLE ... ALTER COLUMN email SET MASK <function>`.

# %%
# %sql
-- Apply mask_email to the email column of retail_catalog64457032.security_lab.customers
ALTER TABLE retail_catalog64457032.security_lab.customers
ALTER COLUMN email SET MASK retail_catalog64457032.security_lab.mask_email;

# %% [markdown]
# ### Task 3.3 — Test the column mask
#
# Query the `customers` table. Since you are the privileged user specified in the mask function, you should see the **real email addresses**.
#
# Any other user querying this table would see `***@***.com` in the `email` column.

# %%
# %sql
-- TODO: Query retail_catalog64457032.security_lab.customers and observe the email column
select * from retail_catalog64457032.security_lab.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>email</th><th>region</th><th>total_spend</th><th>tier</th></tr></thead><tbody><tr><td>1</td><td>Alice Johnson</td><td>***@***.com</td><td>North</td><td>5200.00</td><td>Standard</td></tr><tr><td>2</td><td>Bob Martinez</td><td>***@***.com</td><td>South</td><td>8100.00</td><td>Premium</td></tr><tr><td>3</td><td>Carol Lee</td><td>***@***.com</td><td>North</td><td>3400.00</td><td>Standard</td></tr><tr><td>4</td><td>David Chen</td><td>***@***.com</td><td>East</td><td>7800.00</td><td>Premium</td></tr><tr><td>5</td><td>Eve Patel</td><td>***@***.com</td><td>West</td><td>6200.00</td><td>Standard</td></tr><tr><td>6</td><td>Frank Kim</td><td>***@***.com</td><td>South</td><td>4100.00</td><td>Standard</td></tr></tbody></table></div>

# %% [markdown]
# ### Task 3.4 — Remove the column mask
#
# Remove the column mask from the `email` column, then query the table again to confirm emails are now fully visible to all users.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I drop a column mask from a Unity Catalog table column?"*
#
# **Hint:** Use `ALTER TABLE ... ALTER COLUMN email DROP MASK`.

# %%
# %sql
-- Remove the column mask from the email column
ALTER TABLE retail_catalog64457032.security_lab.customers
ALTER COLUMN email DROP MASK;

-- Query the table to confirm email addresses are now unmasked
SELECT * FROM retail_catalog64457032.security_lab.customers;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>customer_name</th><th>email</th><th>region</th><th>total_spend</th><th>tier</th></tr></thead><tbody><tr><td>1</td><td>Alice Johnson</td><td>alice@northmart.com</td><td>North</td><td>5200.00</td><td>Standard</td></tr><tr><td>2</td><td>Bob Martinez</td><td>bob@northmart.com</td><td>South</td><td>8100.00</td><td>Premium</td></tr><tr><td>3</td><td>Carol Lee</td><td>carol@northmart.com</td><td>North</td><td>3400.00</td><td>Standard</td></tr><tr><td>4</td><td>David Chen</td><td>david@northmart.com</td><td>East</td><td>7800.00</td><td>Premium</td></tr><tr><td>5</td><td>Eve Patel</td><td>eve@northmart.com</td><td>West</td><td>6200.00</td><td>Standard</td></tr><tr><td>6</td><td>Frank Kim</td><td>frank@northmart.com</td><td>South</td><td>4100.00</td><td>Standard</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 4: Azure Key Vault Secrets
#
# NorthMart Retail's loyalty platform requires an API key to connect. Storing this key in plain text inside a notebook is a security risk. In this exercise you retrieve the API key securely from the Azure Key Vault-backed secret scope you created during lab setup.
#
# > ⚠️ Before running the cells in this exercise, ensure you have completed the Key Vault setup steps in the lab instructions (create Key Vault, add secret `loyalty-api-key`, create secret scope `retail-kv-scope`).

# %% [markdown]
# ### Task 4.1 — List available secrets in the scope
#
# List all secrets available in the `retail-kv-scope` secret scope to confirm that `loyalty-api-key` is accessible.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I list the secrets in a Databricks secret scope using dbutils?"*
#
# **Hint:** Use `dbutils.secrets.list("scope-name")`. This returns key names only — never secret values.

# %%
# List all secrets in the retail-kv-scope and display the output
secrets = dbutils.secrets.list("retail-kv-scope")
for secret in secrets:
    print(secret)
# Out:
# SecretMetadata(key='loyalty-api-key')

# %% [markdown]
# ### Task 4.2 — Retrieve the API key securely in Python
#
# Retrieve the `loyalty-api-key` secret from the `retail-kv-scope` scope and assign it to a variable. Then print it.
#
# Observe how Azure Databricks **automatically redacts** the value in the notebook output — you will see `[REDACTED]` instead of the actual key.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I retrieve a secret from a Databricks secret scope using dbutils.secrets.get and why is the output redacted?"*

# %%
# Retrieve the loyalty-api-key from retail-kv-scope
api_key = dbutils.secrets.get(scope="retail-kv-scope", key="loyalty-api-key")

# Print the api_key variable and observe that the output is [REDACTED]
# Databricks automatically redacts secret values in notebook output to prevent accidental exposure
print(api_key)
# Out:
# [REDACTED]

# %% [markdown]
# ### Task 4.3 — Use the secret to simulate a connection string
#
# Construct a connection string that embeds the API key, simulating how it would be used to connect to NorthMart's loyalty platform. Print the connection string and observe that the secret value is still redacted.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I safely use a Databricks secret inside an f-string for a connection string without exposing the value?"*

# %%
# Build a connection string using the api_key variable
connection_string = f"https://loyalty.northmart.com/api?key={api_key}"

# Print the connection string
# The secret value will appear as [REDACTED] in the output because Databricks automatically masks secrets
print(connection_string)
# Out:
# https://loyalty.northmart.com/api?key=[REDACTED]

# %% [markdown]
# ### Task 4.4 — Retrieve the secret using SQL
#
# Retrieve the same secret using the `secret()` SQL function. This is useful when constructing SQL-based connections.
#
# Note that the output is also redacted in SQL results.
#
# > 🤖 **Genie Code tip:** Ask:
# > *"How do I use the secret() function in Databricks SQL to retrieve a secret from a scope?"*

# %%
# %sql
-- Use the secret() SQL function to retrieve loyalty-api-key from retail-kv-scope
SELECT secret('retail-kv-scope', 'loyalty-api-key');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>secret('retail-kv-scope','loyalty-api-key')</th></tr></thead><tbody><tr><td>[REDACTED]</td></tr></tbody></table></div>

# %% [markdown]
# ## Cleanup
#
# Run the cell below to remove all objects created during this lab.

# %%
# %sql
-- Remove all lab objects
ALTER TABLE retail_catalog64457032.security_lab.customers DROP ROW FILTER;
ALTER TABLE retail_catalog64457032.security_lab.customers ALTER COLUMN email DROP MASK;
DROP TABLE IF EXISTS retail_catalog64457032.security_lab.customers;
DROP FUNCTION IF EXISTS retail_catalog64457032.security_lab.region_filter;
DROP FUNCTION IF EXISTS retail_catalog64457032.security_lab.mask_email;
DROP SCHEMA IF EXISTS retail_catalog64457032.security_lab;
DROP CATALOG IF EXISTS retail_catalog64457032 CASCADE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
